# %%
from _lib.paths import (
    REPO_ROOT,
    DATA_ROOT,
    TABLE_DIR,
    FIG_DIR,
    iter_indicators_dirs,
    iter_indicator_files,
)

print("REPO_ROOT:", REPO_ROOT)
print("DATA_ROOT:", DATA_ROOT)
print("TABLE_DIR exists:", TABLE_DIR.exists())
print("FIG_DIR exists:", FIG_DIR.exists())

ind_dirs = iter_indicators_dirs()
print("Number of INDICATORS dirs found:", len(ind_dirs))
for d in ind_dirs[:5]:
    print(" -", d)

files = list(iter_indicator_files("*.nc"))
print("Total NetCDF indicator files found:", len(files))
print("Example file:", files[0] if files else "NONE")
# Out:
# REPO_ROOT: C:\Users\reinhvlr\OneDrive\Documents\RUB\Projects\CARMINE\Work\carmine-analyses\data\CARMINE-T2.4VR\CARMINE-T2.4
# DATA_ROOT: C:\Users\reinhvlr\OneDrive\Documents\RUB\Projects\CARMINE\Work\carmine-analyses\data\CARMINE-T2.4VR\CARMINE-T2.4
# TABLE_DIR exists: True
# FIG_DIR exists: True
# Number of INDICATORS dirs found: 8
#  - C:\Users\reinhvlr\OneDrive\Documents\RUB\Projects\CARMINE\Work\carmine-analyses\data\CARMINE-T2.4VR\CARMINE-T2.4\Athens\INDICATORS
#  - C:\Users\reinhvlr\OneDrive\Documents\RUB\Projects\CARMINE\Work\carmine-analyses\data\CARMINE-T2.4VR\CARMINE-T2.4\Barcelona\INDICATORS
#  - C:\Users\reinhvlr\OneDrive\Documents\RUB\Projects\CARMINE\Work\carmine-analyses\data\CARMINE-T2.4VR\CARMINE-T2.4\Birmingham\INDICATORS
#  - C:\Users\reinhvlr\OneDrive\Documents\RUB\Projects\CARMINE\Work\carmine-analyses\data\CARMINE-T2.4VR\CARMINE-T2.4\Bologna\INDICATORS
# ...

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# C:\Users\localadmin\miniconda3\envs\carmine\python.exe
# 3.11.14 | packaged by conda-forge | (main, Oct 22 2025, 22:35:28) [MSC v.1944 64 bit (AMD64)]
